# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

# %%
df = pd.read_excel(r'Exercice4_resultat_szabo-alexandre.xlsx')
df
# Out:
#                   titre  prix  pieces  nb_chambre  surface (m²)      etage  \
# 0    Appartement meublé  2600     2.0         1.0          44.0  Étage 2/6
# 1    Appartement meublé  7800     4.0         3.0         170.0  Étage 5/9
# 2    Appartement meublé  3500     3.0         2.0          60.0  Étage 6/6
# 3    Appartement meublé  4200     2.0         1.0          57.0  Étage 5/5
# 4    Appartement meublé  2100     2.0         1.0          35.0  Étage 3/6
# ..                  ...   ...     ...         ...           ...        ...
# 255       Studio meublé  1050     NaN         NaN          16.0  Étage 0/6
# 256       Studio meublé   990     NaN         NaN          19.0        NaN
# 257         Appartement  1457     2.0         1.0          18.0        NaN
# 258              Studio  1194     NaN         NaN          36.0        NaN
# 259       Duplex meublé  4800     3.0         2.0         146.0        NaN
#
#      ascenseur  terrasse  balcon  garage    box  meuble  \
# 0        False     False   False   False  False    True
# 1         True     False    True   False  False    True
# 2         True     False   False   False  False    True
# 3         True     False   False   False  False    True
# 4        False     False   False   False  False    True
# ..         ...       ...     ...     ...    ...     ...
# 255      False     False   False   False  False    True
# 256      False     False   False   False  False   False
# 257      False     False   False   False  False   False
# 258       True     False   False   False  False   False
# 259      False      True   False   False  False    True
#
#                                          adresse
# 0           Porte Dauphine à Paris 16ème (75116)
# 1             Auteuil Nord à Paris 16ème (75016)
# 2           Porte Dauphine à Paris 16ème (75116)
# 3             Triangle d'Or à Paris 8ème (75008)
# 4              Muette Nord à Paris 16ème (75116)
# ..                                           ...
# 255                 Arsenal à Paris 4ème (75004)
# 256            Muette Nord à Paris 16ème (75116)
# 257  Bassin de la Villette à Paris 19ème (75019)
# 258               Chaillot à Paris 16ème (75016)
# 259   Pasteur Montparnasse à Paris 15ème (75015)
#
# [260 rows x 13 columns]

# %%
df[df["adresse"].str.contains("75116")]
df[(df["prix"]>=2000)]
# Out:
#                   titre  prix  pieces  nb_chambre  surface (m²)      etage  \
# 0    Appartement meublé  2600     2.0         1.0          44.0  Étage 2/6
# 1    Appartement meublé  7800     4.0         3.0         170.0  Étage 5/9
# 2    Appartement meublé  3500     3.0         2.0          60.0  Étage 6/6
# 3    Appartement meublé  4200     2.0         1.0          57.0  Étage 5/5
# 4    Appartement meublé  2100     2.0         1.0          35.0  Étage 3/6
# ..                  ...   ...     ...         ...           ...        ...
# 250         Appartement  2310     3.0         1.0          75.0  Étage 7/8
# 252  Appartement meublé  3500     3.0         2.0          75.0        NaN
# 253         Appartement  6702     5.0         3.0         182.0  Étage 3/7
# 254         Appartement  2700     3.0         2.0          90.0        NaN
# 259       Duplex meublé  4800     3.0         2.0         146.0        NaN
#
#      ascenseur  terrasse  balcon  garage    box  meuble  \
# 0        False     False   False   False  False    True
# 1         True     False    True   False  False    True
# 2         True     False   False   False  False    True
# 3         True     False   False   False  False    True
# 4        False     False   False   False  False    True
# ..         ...       ...     ...     ...    ...     ...
# 250      False     False    True   False  False   False
# 252       True     False   False   False  False    True
# 253       True     False   False   False  False   False
# 254      False     False   False   False  False   False
# 259      False      True   False   False  False    True
#
#                                         adresse
# 0          Porte Dauphine à Paris 16ème (75116)
# 1            Auteuil Nord à Paris 16ème (75016)
# 2          Porte Dauphine à Paris 16ème (75116)
# 3            Triangle d'Or à Paris 8ème (75008)
# 4             Muette Nord à Paris 16ème (75116)
# ..                                          ...
# 250         Saint Lambert à Paris 15ème (75015)
# 252              Les Halles à Paris 1er (75001)
# 253  Notre Dame des Champs à Paris 6ème (75006)
# 254           Parc Monceau à Paris 8ème (75008)
# 259  Pasteur Montparnasse à Paris 15ème (75015)
#
# [152 rows x 13 columns]

# %%
sb.boxplot(x='pieces',y="prix",data=df)
sb.despine(offset=10,trim=True)

# %%
sb.boxplot(x='nb_chambre',y="prix",data=df,hue="balcon")
sb.despine(offset=10,trim=True)

# %%
df_float = df[["pieces"]]
